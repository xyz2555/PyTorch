# %%
import torch
import numpy as np

# x = torch.empty(3, 3, 3)
# print(x)

# y = torch.rand(2,2)
# print(y)

# z = torch.ones(3,3)
# print(z)

# x = torch.rand(2,2)
# y - torch.rand(2,2)

# print(x)
# print(y)

# z = x + y
# print(z)

# y.add_(x)
# print(y)

# z = torch.sub(x,y)
# print(z)

# x = torch.rand(4,4)
# print(x)
# y = x.view(16)
# print(y)

# a = torch.ones(5)
# print(type(a))

# b = a.numpy()
# print(type(b))

# a.add_(1)
# print(a)
# print(b)

# a = np.ones(5)
# print(a)
# b = torch.from_numpy(a)
# print(b)

# a += 1
# print(a)
# print(b)

# if torch.cuda.is_available():
#     device = torch.device("cuda")
#     x = torch.ones(5, device=device)

#     y = torch.ones(5)
#     y = y.to(device)
#     z = x+y
#     z = z.to("cpu")

x = torch.ones(5, requires_grad=True)
print(x)

# %%
import torch              # Mengimpor library PyTorch untuk komputasi tensor dan deep learning
import numpy as np        # Mengimpor NumPy untuk operasi array numerik

# x = torch.empty(3, 3, 3)
# Membuat tensor 3x3x3 dengan nilai acak (tidak diinisialisasi / garbage value)

# print(x)
# Menampilkan isi tensor x ke layar

# y = torch.rand(2,2)
# Membuat tensor 2x2 dengan nilai acak antara 0 dan 1

# print(y)
# Menampilkan tensor y

# z = torch.ones(3,3)
# Membuat tensor 3x3 yang seluruh elemennya bernilai 1

# print(z)
# Menampilkan tensor z

# x = torch.rand(2,2)
# Membuat tensor x berukuran 2x2 dengan nilai acak

# y - torch.rand(2,2)
# Membuat tensor acak 2x2 (baris ini tidak disimpan, jadi tidak berpengaruh)

# print(x)
# Menampilkan tensor x

# print(y)
# Menampilkan tensor y

# z = x + y
# Menjumlahkan tensor x dan y (operasi tidak in-place)

# print(z)
# Menampilkan hasil penjumlahan x dan y

# y.add_(x)
# Menambahkan x ke y secara in-place (nilai y berubah langsung)

# print(y)
# Menampilkan tensor y setelah ditambah x

# z = torch.sub(x,y)
# Mengurangkan y dari x dan menyimpannya ke z

# print(z)
# Menampilkan hasil pengurangan

# x = torch.rand(4,4)
# Membuat tensor 4x4 dengan nilai acak

# print(x)
# Menampilkan tensor x

# y = x.view(16)
# Mengubah bentuk tensor x menjadi vektor 1D berisi 16 elemen (reshape)

# print(y)
# Menampilkan tensor y hasil reshape

# a = torch.ones(5)
# Membuat tensor PyTorch berisi 5 elemen bernilai 1

# print(type(a))
# Menampilkan tipe data a (torch.Tensor)

# b = a.numpy()
# Mengonversi tensor PyTorch menjadi array NumPy (shared memory)

# print(type(b))
# Menampilkan tipe data b (numpy.ndarray)

# a.add_(1)
# Menambahkan 1 ke tensor a secara in-place

# print(a)
# Menampilkan tensor a setelah ditambah 1

# print(b)
# Menampilkan array NumPy b (ikut berubah karena shared memory)

# a = np.ones(5)
# Membuat array NumPy berisi 5 elemen bernilai 1

# print(a)
# Menampilkan array NumPy a

# b = torch.from_numpy(a)
# Mengonversi array NumPy menjadi tensor PyTorch (shared memory)

# print(b)
# Menampilkan tensor b

# a += 1
# Menambahkan 1 ke array NumPy a secara in-place

# print(a)
# Menampilkan array a setelah ditambah 1

# print(b)
# Menampilkan tensor b (ikut berubah karena shared memory)

# if torch.cuda.is_available():
# Mengecek apakah GPU (CUDA) tersedia

#     device = torch.device("cuda")
#     Menentukan device GPU

#     x = torch.ones(5, device=device)
#     Membuat tensor berisi 1 langsung di GPU

#     y = torch.ones(5)
#     (SALAH KETIK) Seharusnya torch.ones(5)

#     y = y.to(device)
#     Memindahkan tensor y ke GPU

#     z = x+y
#     Menjumlahkan tensor di GPU

#     z = z.to("cpu")
#     Memindahkan hasil kembali ke CPU

x = torch.ones(5, requires_grad=True)
# Membuat tensor berisi 5 elemen bernilai 1 dan mengaktifkan autograd
# (akan melacak operasi untuk keperluan backpropagation)

print(x)
# Menampilkan tensor x beserta informasi requires_grad=True

# RINGKASAN:
# Kode ini memperkenalkan dasar PyTorch, meliputi pembuatan tensor,
# operasi matematika, in-place vs non-in-place operation, reshape,
# konversi antara PyTorch dan NumPy (shared memory),
# penggunaan GPU (CUDA), serta konsep autograd untuk deep learning.
